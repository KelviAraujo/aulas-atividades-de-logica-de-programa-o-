# %%
nome = input("Digite o nome: ")
idade = int(input("Digite a idade: "))
curso = input("Digite o curso: ")

print("----------------")
print("Nome:", nome)
print("Idade:", idade)
print("Curso:", curso)
# Out:
# ----------------
# Nome: kelve
# Idade: 19
# Curso: tecnologia da informação

# %%
num_inteiro = int(input("Digite um número inteiro: "))
num_real = float(input("Digite um número decimal: "))

print(f"Valor:", num_inteiro, "Tipo:", type(num_inteiro))
print(f"Valor:", num_real, "Tipo:", type(num_real))
# Out:
# Valor: 25 Tipo: <class 'int'>
# Valor: 30.8 Tipo: <class 'float'>

# %%
texto_digitado = input("digite um numero: ")
numero_convertido =int(texto_digitado)

print("valor final", texto_digitado )
print("numero convertido", type(numero_convertido))
# Out:
# valor final 20
# numero convertido <class 'int'>

# %%
nome =input("digite seu nome")
nascimento =input("digite o ano de nascimento")

print("nome:", nome)
print("idade", 2026-nascimento)
# Out:
# nome: kelve
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 5
#       2 nascimento =input("digite o ano de nascimento")
#       4 print("nome:", nome)
# ----> 5 print("idade", 2026-nascimento)
#
# TypeError: unsupported operand type(s) for -: 'int' and 'str'
